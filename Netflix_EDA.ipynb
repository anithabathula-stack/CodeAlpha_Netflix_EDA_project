# %%
import pandas as pd

# %%
df = pd.read_csv("data/netflix_titles.csv")

# %%
import os

print(os.path.isfile("data/netflix_titles.csv"))
print(os.access("data/netflix_titles.csv", os.R_OK))
# Out:
# True
# True

# %%
import os

print(os.path.isfile("data/netflix_titles.csv"))
print(os.access("data/netflix_titles.csv", os.R_OK))
# Out:
# True
# True

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\HP\Documents\CodeAlpha_Netflix _EDA project
# ['data', 'Netflix_EDA.ipynb']

# %%
import os

print(os.listdir("data"))
# Out:
# ['netflix_titles.csv']

# %%
df = pd.read_csv("data/netflix_titles.csv")

# %%
import os

print("Is file:", os.path.isfile("data/netflix_titles.csv"))
print("Is folder:", os.path.isdir("data/netflix_titles.csv"))
# Out:
# Is file: True
# Is folder: False

# %%
import pandas as pd

df = pd.read_csv("data/netflix_titles.csv")

df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
import os
print(os.path.isfile("data/netflix_titles.csv"))
# Out:
# True

# %%
df = pd.read_csv("data/netflix_titles.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data/netflix_titles.csv")

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.describe(include="all")
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
# mean       NaN    NaN                   NaN            NaN
# std        NaN    NaN                   NaN            NaN
# min        NaN    NaN                   NaN            NaN
# 25%        NaN    NaN                   NaN            NaN
# 50%        NaN    NaN                   NaN            NaN
# 75%        NaN    NaN                   NaN            NaN
# max        NaN    NaN                   NaN            NaN
#
#                       cast        country       date_added  release_year  \
# count                 7982           7976             8797   8807.000000
# unique                7692            748             1767           NaN
# ...

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="type")
plt.title("Movies vs TV Shows")
plt.xlabel("Type")
plt.ylabel("Count")
plt.show()

# %%
top_countries = df["country"].value_counts().head(10)

plt.figure(figsize=(10,5))
top_countries.plot(kind="bar")
plt.title("Top 10 Countries by Number of Netflix Titles")
plt.xlabel("Country")
plt.ylabel("Number of Titles")
plt.xticks(rotation=45)
plt.show()

# %%
df["date_added"] = pd.to_datetime(df["date_added"], errors="coerce")

year_added = df["date_added"].dt.year.value_counts().sort_index()

plt.figure(figsize=(10,5))
year_added.plot(kind="line", marker="o")
plt.title("Netflix Titles Added by Year")
plt.xlabel("Year")
plt.ylabel("Number of Titles")
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.histplot(df["release_year"], bins=30)
plt.title("Distribution of Release Years")
plt.xlabel("Release Year")
plt.ylabel("Number of Titles")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, x="rating", order=df["rating"].value_counts().index)
plt.title("Netflix Titles by Rating")
plt.xlabel("Rating")
plt.ylabel("Number of Titles")
plt.xticks(rotation=45)
plt.show()

# %%
year_type = df.groupby(["release_year", "type"]).size().unstack(fill_value=0)

year_type.plot(figsize=(12,6))
plt.title("Movies vs TV Shows by Release Year")
plt.xlabel("Release Year")
plt.ylabel("Number of Titles")
plt.show()

# %% [markdown]
# # Key Findings
#
# - Netflix contains both Movies and TV Shows.
# - Movies are more numerous than TV Shows in the dataset.
# - Netflix content has increased significantly over the years.
# - The United States is one of the major countries contributing content.
# - The dataset contains a wide variety of ratings and content types.
# - Most Netflix titles were released in recent years.
# - The analysis shows that Netflix has a diverse collection of movies and TV shows.

# %% [markdown]
# # Conclusion
#
# Exploratory Data Analysis was performed on the Netflix titles dataset to understand the distribution and characteristics of Netflix content. The analysis examined content types, countries, ratings, release years, and the growth of titles over time. Visualizations helped identify important patterns and trends in the dataset. Overall, Netflix provides a diverse collection of movies and TV shows from different countries and years.
